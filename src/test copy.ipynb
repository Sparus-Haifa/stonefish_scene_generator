# %% [markdown]
# # Deepersense: sim data generator

# %% [markdown]
# ## imports

# %%
import os
# import sys
import rospy
import rosbag
import rospkg
import glob

# %%
from simulation_controller import SimulationController
from scene_generator import SceneGenerator, ColorMap
from launchfile_maker import LaunchFileMaker

# %% [markdown]
# ## file manager

# %% [markdown]
# ### cwd

# %%
cwd = os.getcwd()

# %% [markdown]
# ### package path

# %%
rospack = rospkg.RosPack()
package_path = rospack.get_path('stonefish_scene_generator')

# %% [markdown]
# ### iterate files in folder

# %%
all_files_path = os.path.join(package_path,'*')
for file_name in glob.glob(all_files_path):
    print(file_name)
# Out:
# /home/zeged/catkin_ws/src/stonefish_scene_generator/launch
# /home/zeged/catkin_ws/src/stonefish_scene_generator/src
# /home/zeged/catkin_ws/src/stonefish_scene_generator/package.xml
# /home/zeged/catkin_ws/src/stonefish_scene_generator/data
# /home/zeged/catkin_ws/src/stonefish_scene_generator/CMakeLists.txt

# %% [markdown]
# ### create data folder

# %%
def create_folder(path):
    dir_exists = os.path.isdir(path)
    if not dir_exists:
        os.mkdir(path)
        print('data folder created: {}'.format(path))

# %%
data_folder_path = os.path.join(package_path, 'data')
create_folder(data_folder_path)

# %% [markdown]
# ## generate stonefish scene

# %% [markdown]
# ## make a scene

# %%
# def make_a_scene(category, main_subject):
#     scene = None
#     title = category + '_' + main_subject
#     seabed_depth = 15
#     gen = SceneGenerator(seabed_depth)
#     gen.add_empty_frame(ColorMap.jet)
#     if main_subject == 'box':
#         gen.add_boxes()
#     else:
#         gen.add_reefs()
#     scene = gen.generate()
#     return scene

# %% [markdown]
# ## categories

# %%
# categories = []
# categories.append('basic')
# categories.append('multiObect')
# shapes = []
# shapes.append('box')
# shapes.append('sphere')
# shapes.append('cylindar')
# reefs = ['2019', '2020']
# for reef in reefs:
#     shapes.append(reef)

# test = [categories, shapes]
# import itertools
# for category, main_subject in list(itertools.product(*test)):
#     print(category, main_subject)
#     scene = make_a_scene(category, main_subject)
# Out:
# ('basic', 'box')
# ('basic', 'sphere')
# ('basic', 'cylindar')
# ('basic', '2019')
# ('basic', '2020')
# ('multiObect', 'box')
# ('multiObect', 'sphere')
# ('multiObect', 'cylindar')
# ('multiObect', '2019')
# ('multiObect', '2020')

# %% [markdown]
# ### generate scene

# %%
title = 'basic'
seabed_depth = 15
gen = SceneGenerator(seabed_depth)
gen.add_empty_frame(ColorMap.jet)
gen.add_reefs()
scene = gen.generate()
# print(scene)

# %% [markdown]
# ### save scene to .scn file

# %%
scene_file_path = os.path.join(data_folder_path, title + '.scn')
f = open(scene_file_path, "w")
f.write(scene)
f.close()

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### get launch_file_path

# %%
launch_file_name = 'auto_generated.launch'
launch_file_path = os.path.join(package_path, 'launch', launch_file_name)
print(launch_file_path)
# Out:
# /home/zeged/catkin_ws/src/stonefish_scene_generator/launch/auto_generated.launch

# %% [markdown]
# ### edit/make launch file

# %%
rate = 300.0
resolution = (1200, 800)
bagfile_path = os.path.join(data_folder_path, title + '.bag')
maker = LaunchFileMaker(scene_file_path, rate, resolution, bagfile_path)
maker.save_to_file(launch_file_path)

# %% [markdown]
# ### setup simulation

# %%
controller = SimulationController(launch_file_path)
# Out:
# ... logging to /home/zeged/.ros/log/138a2ef6-28c2-11ec-aa88-107b448dffed/roslaunch-zeged-System-Product-Name-3772.log

# %% [markdown]
# ### launch simulation

# %%
controller.run()
controller.wait_for_ros()
# Out:
# started roslaunch server http://zeged-System-Product-Name:46283/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /rosdistro: melodic
#  * /rosversion: 1.14.11
#
# NODES
#   /
#     rosbag_record_cam (rosbag/record)
#     rviz (rviz/rviz)
#     stonefish_simulator (stonefish_ros/parsed_simulator)
#
# auto-starting new master
# process[master]: started with pid [3819]
# ROS_MASTER_URI=http://localhost:11311
# setting /run_id to 138a2ef6-28c2-11ec-aa88-107b448dffed
# process[rosout-1]: started with pid [3837]
# started core service [/rosout]
# process[stonefish_simulator-2]: started with pid [3840]
# process[rviz-3]: started with pid [3845]
# process[rosbag_record_cam-4]: started with pid [3846]
# [INFO] [1633757456.833538]: started
# [INFO] [1633757456.833895]: waiting for topic msg
# waiting for message
# wait is over
# rospy.get_time() - self.timer > 15
# (1633757485.684022, 1633757470.683414)
# [INFO] [1633757485.684169]: timeout: shutting down
# [rosbag_record_cam-4] killing on exit
# [rviz-3] killing on exit
# [stonefish_simulator-2] killing on exit
# [rosout-1] killing on exit
# [master] killing on exit

# %% [markdown]
# ## Bag

# %% [markdown]
# ### open bag file

# %%
import rospy
from collections import defaultdict
import cv2
import numpy as np
from cv_bridge import CvBridge

# %% [markdown]
# bag = rosbag.Bag(bagfile, 'r')

# %% [markdown]
# ## open bag file

# %%
bag = rosbag.Bag(bagfile_path, 'r')

# %% [markdown]
# ## create a folder for images

# %%
image_folder_path = bagfile_path.split('.')[0]
print(image_folder_path)
create_folder(image_folder_path)
# Out:
# /home/zeged/catkin_ws/src/stonefish_scene_generator/data/basic
# data folder created: /home/zeged/catkin_ws/src/stonefish_scene_generator/data/basic

# %%
def imshow(win, img):
    cv2.imshow(win, img)
    cv2.waitKey(10)

# %%
def process_image(msg, topic):
    bridge = CvBridge()
    encoding = 'bgr8'
    img = np.asarray(bridge.imgmsg_to_cv2(msg, encoding))
    return img

# %%
def process_depth(msg, topic):
    bridge = CvBridge()
    encoding = '32FC1'
    img = np.asarray(bridge.imgmsg_to_cv2(msg, encoding))
    return img

# %%
def normaliaze_depth(msg):
    cv_image_array = np.array(msg, dtype = np.dtype('f8'))
    slice1Copy = cv_image_norm = cv2.normalize(cv_image_array, cv_image_array, 0, 1, cv2.NORM_MINMAX)
    slice1Copy = np.uint8(slice1Copy*255)
    return(slice1Copy)

# %%
def save_image(img, filename):
    # print(file_name)
    cv2.imwrite(filename, img)

# %%
iterator = bag.read_messages()
counter = defaultdict(lambda: 0)
image_num = 0
for topic, msg, time in iterator:
    msg_time = rospy.Time.to_sec(time) # .to_time(time)
    msg_type = str(type(msg)).split('__')[1].split("'")[0]
    print(msg_time, msg_type, topic)
    counter[topic]+=1
    if msg_type == 'CameraInfo':
        continue
    image_num += 1

    if 'image_color' in topic or 'display' in topic:
        bridged_image = process_image(msg, str(topic))
        imshow(topic, bridged_image)
        file_name = os.path.join(image_folder_path, str(image_num) + '.tif')
        save_image(bridged_image, file_name)



    elif 'image_depth2/image_depth' in topic:
        bridged_image = process_depth(msg, str(topic))
        norm_image = normaliaze_depth(bridged_image)
        imshow(topic, norm_image)
        file_name = os.path.join(image_folder_path, str(image_num) + '.tif')
        save_image(norm_image, file_name)
    else:
        print(topic)

cv2.destroyAllWindows()
# Out:
# (1633757470.6486912, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757470.680808, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757470.6824439, 'Image', '/camera2/image_raw/image_color')
# (1633757470.7029753, 'CameraInfo', '/image_depth2/camera_info')
# (1633757470.7046473, 'Image', '/image_depth2/image_depth')
# (1633757470.7517152, 'CameraInfo', '/image_depth2/camera_info')
# (1633757470.7529461, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757470.7532976, 'Image', '/image_depth2/image_depth')
# (1633757470.7542408, 'Image', '/camera2/image_raw/image_color')
# (1633757470.7803667, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757470.8302991, 'CameraInfo', '/image_depth2/camera_info')
# (1633757470.8309119, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757470.8317757, 'Image', '/image_depth2/image_depth')
# (1633757470.8320181, 'Image', '/camera2/image_raw/image_color')
# (1633757470.8738651, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757470.9233935, 'CameraInfo', '/image_depth2/camera_info')
# (1633757470.924096, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757470.9252665, 'Image', '/camera2/image_raw/image_color')
# (1633757470.9254146, 'Image', '/image_depth2/image_depth')
# (1633757470.9521005, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757470.9836445, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757470.9849238, 'Image', '/camera2/image_raw/image_color')
# (1633757471.029018, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.0301828, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.0306916, 'Image', '/camera2/image_raw/image_color')
# (1633757471.0310674, 'Image', '/image_depth2/image_depth')
# (1633757471.0314102, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.0628626, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.0632503, 'Image', '/camera2/image_raw/image_color')
# (1633757471.1089509, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.1099603, 'Image', '/image_depth2/image_depth')
# (1633757471.1103494, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.1108706, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.1109521, 'Image', '/camera2/image_raw/image_color')
# (1633757471.1565738, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.156858, 'Image', '/camera2/image_raw/image_color')
# (1633757471.203808, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.2046037, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.2052448, 'Image', '/camera2/image_raw/image_color')
# (1633757471.2052555, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.2058966, 'Image', '/image_depth2/image_depth')
# (1633757471.23693, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.2381344, 'Image', '/camera2/image_raw/image_color')
# (1633757471.2827399, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.2835689, 'Image', '/image_depth2/image_depth')
# (1633757471.2839496, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.2847416, 'Image', '/camera2/image_raw/image_color')
# (1633757471.2852137, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.337224, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.3380373, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.3382862, 'Image', '/image_depth2/image_depth')
# (1633757471.3384554, 'Image', '/camera2/image_raw/image_color')
# (1633757471.3658822, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.4145033, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.415343, 'Image', '/image_depth2/image_depth')
# (1633757471.415469, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.4159868, 'Image', '/camera2/image_raw/image_color')
# (1633757471.475992, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.4764466, 'Image', '/camera2/image_raw/image_color')
# (1633757471.4767368, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.4975324, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.4979227, 'Image', '/image_depth2/image_depth')
# (1633757471.5280335, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.5284257, 'Image', '/camera2/image_raw/image_color')
# (1633757471.5739944, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.5749497, 'Image', '/image_depth2/image_depth')
# (1633757471.575175, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.5760496, 'Image', '/camera2/image_raw/image_color')
# (1633757471.5761843, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.6049922, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.6553535, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.656028, 'Image', '/image_depth2/image_depth')
# (1633757471.6563692, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.6568522, 'Image', '/camera2/image_raw/image_color')
# (1633757471.6987476, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.748041, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.7489357, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.7491293, 'Image', '/image_depth2/image_depth')
# (1633757471.749402, 'Image', '/camera2/image_raw/image_color')
# (1633757471.776726, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.8263905, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.827169, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.827518, 'Image', '/camera2/image_raw/image_color')
# (1633757471.827553, 'Image', '/image_depth2/image_depth')
# (1633757471.8735998, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.8739102, 'Image', '/camera2/image_raw/image_color')
# (1633757471.919728, 'CameraInfo', '/image_depth2/camera_info')
# (1633757471.920585, 'Image', '/image_depth2/image_depth')
# (1633757471.9208913, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757471.9215782, 'Image', '/camera2/image_raw/image_color')
# (1633757471.9218588, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757471.9637384, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.0136795, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.014343, 'Image', '/image_depth2/image_depth')
# (1633757472.0145931, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.0151443, 'Image', '/camera2/image_raw/image_color')
# (1633757472.0426302, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.0913506, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.092229, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.0923634, 'Image', '/image_depth2/image_depth')
# (1633757472.0929375, 'Image', '/camera2/image_raw/image_color')
# (1633757472.1519485, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.1526067, 'Image', '/camera2/image_raw/image_color')
# (1633757472.1526532, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.1739922, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.174737, 'Image', '/image_depth2/image_depth')
# (1633757472.2040536, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.20439, 'Image', '/camera2/image_raw/image_color')
# (1633757472.2508814, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.2518437, 'Image', '/image_depth2/image_depth')
# (1633757472.25207, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.2528768, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.2528894, 'Image', '/camera2/image_raw/image_color')
# (1633757472.2839408, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.2843254, 'Image', '/camera2/image_raw/image_color')
# (1633757472.3306663, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.3315926, 'Image', '/image_depth2/image_depth')
# (1633757472.3320346, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.332661, 'Image', '/camera2/image_raw/image_color')
# (1633757472.332795, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.363929, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.3643625, 'Image', '/camera2/image_raw/image_color')
# (1633757472.4094877, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.4104962, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.4105172, 'Image', '/image_depth2/image_depth')
# (1633757472.4112608, 'Image', '/camera2/image_raw/image_color')
# (1633757472.411419, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.4639034, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.4648228, 'Image', '/image_depth2/image_depth')
# (1633757472.4648736, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.4660466, 'Image', '/camera2/image_raw/image_color')
# (1633757472.4934387, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.543504, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.5442915, 'Image', '/image_depth2/image_depth')
# (1633757472.5446455, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.5452096, 'Image', '/camera2/image_raw/image_color')
# (1633757472.5866482, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.6368217, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.6373947, 'Image', '/image_depth2/image_depth')
# (1633757472.6378312, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.63829, 'Image', '/camera2/image_raw/image_color')
# (1633757472.666057, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.715759, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.7167127, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.716759, 'Image', '/image_depth2/image_depth')
# (1633757472.7171953, 'Image', '/camera2/image_raw/image_color')
# (1633757472.744964, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.7941468, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.7948637, 'Image', '/image_depth2/image_depth')
# (1633757472.7952375, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.7956634, 'Image', '/camera2/image_raw/image_color')
# (1633757472.822978, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.8728843, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.8736024, 'Image', '/image_depth2/image_depth')
# (1633757472.873925, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.8745089, 'Image', '/camera2/image_raw/image_color')
# (1633757472.901225, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757472.9510226, 'CameraInfo', '/image_depth2/camera_info')
# (1633757472.9517488, 'Image', '/image_depth2/image_depth')
# (1633757472.9529426, 'Image', '/camera2/image_raw/image_color')
# (1633757472.9529607, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757472.9807005, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.0311537, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.0320618, 'Image', '/image_depth2/image_depth')
# (1633757473.0320895, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.032621, 'Image', '/camera2/image_raw/image_color')
# (1633757473.0788474, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.0791702, 'Image', '/camera2/image_raw/image_color')
# (1633757473.12531, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.1263525, 'Image', '/image_depth2/image_depth')
# (1633757473.1265073, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.1271374, 'Image', '/camera2/image_raw/image_color')
# (1633757473.1276891, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.1690478, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.2182918, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.2191029, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.2191036, 'Image', '/image_depth2/image_depth')
# (1633757473.219756, 'Image', '/camera2/image_raw/image_color')
# (1633757473.2795556, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.280095, 'Image', '/camera2/image_raw/image_color')
# (1633757473.280302, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.3010352, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.3017678, 'Image', '/image_depth2/image_depth')
# (1633757473.3612704, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.3620336, 'Image', '/image_depth2/image_depth')
# (1633757473.362355, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.3630385, 'Image', '/camera2/image_raw/image_color')
# (1633757473.3631268, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.394867, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.3951044, 'Image', '/camera2/image_raw/image_color')
# (1633757473.4412794, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.4422216, 'Image', '/image_depth2/image_depth')
# (1633757473.4425297, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.443226, 'Image', '/camera2/image_raw/image_color')
# (1633757473.4433126, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.4746294, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.4749813, 'Image', '/camera2/image_raw/image_color')
# (1633757473.5210807, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.5220842, 'Image', '/image_depth2/image_depth')
# (1633757473.5221593, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.5228002, 'Image', '/camera2/image_raw/image_color')
# (1633757473.5230122, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.5682282, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.5685647, 'Image', '/camera2/image_raw/image_color')
# (1633757473.6143517, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.6152084, 'Image', '/image_depth2/image_depth')
# (1633757473.6153917, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.6161385, 'Image', '/camera2/image_raw/image_color')
# (1633757473.6161385, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.6670525, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.667792, 'Image', '/image_depth2/image_depth')
# (1633757473.668205, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.6688898, 'Image', '/camera2/image_raw/image_color')
# (1633757473.6969023, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.7471263, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.7478237, 'Image', '/image_depth2/image_depth')
# (1633757473.748133, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.748565, 'Image', '/camera2/image_raw/image_color')
# (1633757473.7903817, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.8401418, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.841025, 'Image', '/image_depth2/image_depth')
# (1633757473.8411949, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.8418188, 'Image', '/camera2/image_raw/image_color')
# (1633757473.869225, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757473.918558, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.919382, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.9194102, 'Image', '/image_depth2/image_depth')
# (1633757473.920098, 'Image', '/camera2/image_raw/image_color')
# (1633757473.9968972, 'CameraInfo', '/image_depth2/camera_info')
# (1633757473.9979706, 'Image', '/image_depth2/image_depth')
# (1633757473.9984672, 'Image', '/camera2/image_raw/image_color')
# (1633757473.9985948, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757473.9991066, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.0271924, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.0764318, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.0772514, 'Image', '/image_depth2/image_depth')
# (1633757474.0773146, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.077675, 'Image', '/camera2/image_raw/image_color')
# (1633757474.1366777, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.1374042, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.1374216, 'Image', '/camera2/image_raw/image_color')
# (1633757474.1584976, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.1589615, 'Image', '/image_depth2/image_depth')
# (1633757474.2178419, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.2186098, 'Image', '/image_depth2/image_depth')
# (1633757474.219069, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.2196603, 'Image', '/camera2/image_raw/image_color')
# (1633757474.219667, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.2647033, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.2650154, 'Image', '/camera2/image_raw/image_color')
# (1633757474.3116872, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.3127136, 'Image', '/image_depth2/image_depth')
# (1633757474.3128862, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.313416, 'Image', '/camera2/image_raw/image_color')
# (1633757474.3136446, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.3451152, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.3454654, 'Image', '/camera2/image_raw/image_color')
# (1633757474.3908834, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.391869, 'Image', '/image_depth2/image_depth')
# (1633757474.3921375, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.3929145, 'Image', '/camera2/image_raw/image_color')
# (1633757474.3930075, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.424476, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.4248614, 'Image', '/camera2/image_raw/image_color')
# (1633757474.4714973, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.472263, 'Image', '/image_depth2/image_depth')
# (1633757474.4726894, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.4732976, 'Image', '/camera2/image_raw/image_color')
# (1633757474.4734278, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.5184436, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.5187871, 'Image', '/camera2/image_raw/image_color')
# (1633757474.565281, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.5660737, 'Image', '/image_depth2/image_depth')
# (1633757474.5665073, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.5672965, 'Image', '/camera2/image_raw/image_color')
# (1633757474.5673273, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.5984712, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.5987973, 'Image', '/camera2/image_raw/image_color')
# (1633757474.6453862, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.6463933, 'Image', '/image_depth2/image_depth')
# (1633757474.646926, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.6475165, 'Image', '/camera2/image_raw/image_color')
# (1633757474.647788, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.692385, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.6926765, 'Image', '/camera2/image_raw/image_color')
# (1633757474.7387838, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.7396643, 'Image', '/image_depth2/image_depth')
# (1633757474.7398458, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.7406435, 'Image', '/camera2/image_raw/image_color')
# (1633757474.7408376, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.7726364, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.7729447, 'Image', '/camera2/image_raw/image_color')
# (1633757474.8182044, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.819079, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.8193297, 'Image', '/image_depth2/image_depth')
# (1633757474.8197803, 'Image', '/camera2/image_raw/image_color')
# (1633757474.8203173, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.8524284, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.8527703, 'Image', '/camera2/image_raw/image_color')
# (1633757474.8730392, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.8736055, 'Image', '/image_depth2/image_depth')
# (1633757474.9014847, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757474.951287, 'CameraInfo', '/image_depth2/camera_info')
# (1633757474.952103, 'Image', '/image_depth2/image_depth')
# (1633757474.9521096, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757474.952677, 'Image', '/camera2/image_raw/image_color')
# (1633757474.9963655, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.046063, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.0467958, 'Image', '/image_depth2/image_depth')
# (1633757475.0470345, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.0474725, 'Image', '/camera2/image_raw/image_color')
# (1633757475.0748441, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.1239965, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.1247988, 'Image', '/image_depth2/image_depth')
# (1633757475.1248212, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.1256247, 'Image', '/camera2/image_raw/image_color')
# (1633757475.1842518, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.1848297, 'Image', '/camera2/image_raw/image_color')
# (1633757475.1853237, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.2050962, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.20567, 'Image', '/image_depth2/image_depth')
# (1633757475.2643933, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.265342, 'Image', '/image_depth2/image_depth')
# (1633757475.2654939, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.266156, 'Image', '/camera2/image_raw/image_color')
# (1633757475.2663207, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.2978086, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.2981265, 'Image', '/camera2/image_raw/image_color')
# (1633757475.3434231, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.3443756, 'Image', '/image_depth2/image_depth')
# (1633757475.3446825, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.3453717, 'Image', '/camera2/image_raw/image_color')
# (1633757475.3455834, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.3769822, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.3773873, 'Image', '/camera2/image_raw/image_color')
# (1633757475.4239213, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.4246063, 'Image', '/image_depth2/image_depth')
# (1633757475.4251482, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.4257178, 'Image', '/camera2/image_raw/image_color')
# (1633757475.4259114, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.4711003, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.4714572, 'Image', '/camera2/image_raw/image_color')
# (1633757475.5173373, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.518085, 'Image', '/image_depth2/image_depth')
# (1633757475.5183017, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.518982, 'Image', '/camera2/image_raw/image_color')
# (1633757475.5190089, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.5511868, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.5514932, 'Image', '/camera2/image_raw/image_color')
# (1633757475.5976503, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.5986133, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.598915, 'Image', '/image_depth2/image_depth')
# (1633757475.599337, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.5993624, 'Image', '/camera2/image_raw/image_color')
# (1633757475.6448357, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.645149, 'Image', '/camera2/image_raw/image_color')
# (1633757475.6905646, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.6914465, 'Image', '/image_depth2/image_depth')
# (1633757475.6915054, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.6920106, 'Image', '/camera2/image_raw/image_color')
# (1633757475.6925235, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.743805, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.7446709, 'Image', '/image_depth2/image_depth')
# (1633757475.744695, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.7452493, 'Image', '/camera2/image_raw/image_color')
# (1633757475.773156, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.827323, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.8287766, 'Image', '/image_depth2/image_depth')
# (1633757475.8292851, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.8300655, 'Image', '/camera2/image_raw/image_color')
# (1633757475.8698213, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.9198842, 'CameraInfo', '/image_depth2/camera_info')
# (1633757475.9207594, 'Image', '/image_depth2/image_depth')
# (1633757475.9208038, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.9213064, 'Image', '/camera2/image_raw/image_color')
# (1633757475.9806027, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757475.9810727, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757475.981223, 'Image', '/camera2/image_raw/image_color')
# (1633757476.0267727, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.0277088, 'Image', '/image_depth2/image_depth')
# (1633757476.0282013, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.0288658, 'Image', '/camera2/image_raw/image_color')
# (1633757476.0291564, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.0600038, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.0603507, 'Image', '/camera2/image_raw/image_color')
# (1633757476.1074727, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.1084685, 'Image', '/image_depth2/image_depth')
# (1633757476.108994, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.1098707, 'Image', '/camera2/image_raw/image_color')
# (1633757476.1104257, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.154723, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.1550133, 'Image', '/camera2/image_raw/image_color')
# (1633757476.2007391, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.201731, 'Image', '/image_depth2/image_depth')
# (1633757476.2017457, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.2025683, 'Image', '/camera2/image_raw/image_color')
# (1633757476.2027152, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.2349076, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.235225, 'Image', '/camera2/image_raw/image_color')
# (1633757476.280536, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.2814305, 'Image', '/image_depth2/image_depth')
# (1633757476.2814858, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.2822204, 'Image', '/camera2/image_raw/image_color')
# (1633757476.2822988, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.31496, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.3153033, 'Image', '/camera2/image_raw/image_color')
# (1633757476.3612237, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.362189, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.3622093, 'Image', '/image_depth2/image_depth')
# (1633757476.362902, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.3630383, 'Image', '/camera2/image_raw/image_color')
# (1633757476.3944983, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.3948538, 'Image', '/camera2/image_raw/image_color')
# (1633757476.4174483, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.4181726, 'Image', '/image_depth2/image_depth')
# (1633757476.4459078, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.446152, 'Image', '/camera2/image_raw/image_color')
# (1633757476.4920342, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.4929094, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.493207, 'Image', '/image_depth2/image_depth')
# (1633757476.4937024, 'Image', '/camera2/image_raw/image_color')
# (1633757476.4939806, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.5384667, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.590558, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.5913968, 'Image', '/image_depth2/image_depth')
# (1633757476.5915616, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.5920734, 'Image', '/camera2/image_raw/image_color')
# (1633757476.6201274, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.6697037, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.6704512, 'Image', '/image_depth2/image_depth')
# (1633757476.6707833, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.671275, 'Image', '/camera2/image_raw/image_color')
# (1633757476.7313426, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.7319052, 'Image', '/camera2/image_raw/image_color')
# (1633757476.7320526, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.752847, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.75318, 'Image', '/image_depth2/image_depth')
# (1633757476.7833273, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.7837305, 'Image', '/camera2/image_raw/image_color')
# (1633757476.8299906, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.83083, 'Image', '/image_depth2/image_depth')
# (1633757476.8312733, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.8317368, 'Image', '/camera2/image_raw/image_color')
# (1633757476.8321633, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.859881, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757476.9097826, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.9106157, 'Image', '/image_depth2/image_depth')
# (1633757476.9108324, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.9115262, 'Image', '/camera2/image_raw/image_color')
# (1633757476.942564, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.9428875, 'Image', '/camera2/image_raw/image_color')
# (1633757476.9897947, 'CameraInfo', '/image_depth2/camera_info')
# (1633757476.9909327, 'Image', '/image_depth2/image_depth')
# (1633757476.9909542, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757476.991608, 'Image', '/camera2/image_raw/image_color')
# (1633757476.9917288, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.0368133, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.0372303, 'Image', '/camera2/image_raw/image_color')
# (1633757477.0831008, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.0839868, 'Image', '/image_depth2/image_depth')
# (1633757477.08436, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.0848913, 'Image', '/camera2/image_raw/image_color')
# (1633757477.0850735, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.1172917, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.1176503, 'Image', '/camera2/image_raw/image_color')
# (1633757477.164385, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.1651456, 'Image', '/image_depth2/image_depth')
# (1633757477.1655548, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.1661398, 'Image', '/camera2/image_raw/image_color')
# (1633757477.1662607, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.1981037, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.1984599, 'Image', '/camera2/image_raw/image_color')
# (1633757477.245516, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.246347, 'Image', '/image_depth2/image_depth')
# (1633757477.246691, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.2472372, 'Image', '/camera2/image_raw/image_color')
# (1633757477.2473912, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.2952268, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.2956135, 'Image', '/camera2/image_raw/image_color')
# (1633757477.34244, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.3433003, 'Image', '/image_depth2/image_depth')
# (1633757477.3436513, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.344196, 'Image', '/camera2/image_raw/image_color')
# (1633757477.3444414, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.3725607, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.4239485, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.4247062, 'Image', '/image_depth2/image_depth')
# (1633757477.4251285, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.4255397, 'Image', '/camera2/image_raw/image_color')
# (1633757477.4712763, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.4715674, 'Image', '/camera2/image_raw/image_color')
# (1633757477.518649, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.5194488, 'Image', '/image_depth2/image_depth')
# (1633757477.51987, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.5204716, 'Image', '/camera2/image_raw/image_color')
# (1633757477.5206544, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.548636, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.5810258, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.581309, 'Image', '/camera2/image_raw/image_color')
# (1633757477.6018524, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.6022122, 'Image', '/image_depth2/image_depth')
# (1633757477.632234, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.6326044, 'Image', '/camera2/image_raw/image_color')
# (1633757477.678723, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.6795108, 'Image', '/image_depth2/image_depth')
# (1633757477.679966, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.680606, 'Image', '/camera2/image_raw/image_color')
# (1633757477.6807086, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.7118719, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.7122767, 'Image', '/camera2/image_raw/image_color')
# (1633757477.7580104, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.758998, 'Image', '/image_depth2/image_depth')
# (1633757477.7594123, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.7598884, 'Image', '/camera2/image_raw/image_color')
# (1633757477.760007, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.8115404, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.812304, 'Image', '/image_depth2/image_depth')
# (1633757477.8125632, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.8130379, 'Image', '/camera2/image_raw/image_color')
# (1633757477.8403585, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.8905413, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.8914607, 'Image', '/image_depth2/image_depth')
# (1633757477.891651, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.8920915, 'Image', '/camera2/image_raw/image_color')
# (1633757477.935433, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757477.9857163, 'CameraInfo', '/image_depth2/camera_info')
# (1633757477.9864058, 'Image', '/image_depth2/image_depth')
# (1633757477.9868376, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757477.9872322, 'Image', '/camera2/image_raw/image_color')
# (1633757478.014738, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.064175, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.064902, 'Image', '/image_depth2/image_depth')
# (1633757478.06531, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.0657196, 'Image', '/camera2/image_raw/image_color')
# (1633757478.0926745, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.1429255, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.1436474, 'Image', '/image_depth2/image_depth')
# (1633757478.144033, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.1444361, 'Image', '/camera2/image_raw/image_color')
# (1633757478.171833, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.2230206, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.223651, 'Image', '/image_depth2/image_depth')
# (1633757478.224036, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.2244053, 'Image', '/camera2/image_raw/image_color')
# (1633757478.2669787, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.3166664, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.317383, 'Image', '/image_depth2/image_depth')
# (1633757478.317802, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.3182538, 'Image', '/camera2/image_raw/image_color')
# (1633757478.3453443, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.394572, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.3952935, 'Image', '/image_depth2/image_depth')
# (1633757478.395515, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.3961637, 'Image', '/camera2/image_raw/image_color')
# (1633757478.4241493, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.4742608, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.475, 'Image', '/image_depth2/image_depth')
# (1633757478.4752781, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.4758697, 'Image', '/camera2/image_raw/image_color')
# (1633757478.502993, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.5529952, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.553779, 'Image', '/image_depth2/image_depth')
# (1633757478.5540311, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.5545352, 'Image', '/camera2/image_raw/image_color')
# (1633757478.597202, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.646858, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.647541, 'Image', '/image_depth2/image_depth')
# (1633757478.6477573, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.6483057, 'Image', '/camera2/image_raw/image_color')
# (1633757478.7068474, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.7074733, 'Image', '/camera2/image_raw/image_color')
# (1633757478.7078412, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.728462, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.7290027, 'Image', '/image_depth2/image_depth')
# (1633757478.7924411, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.7937841, 'Image', '/image_depth2/image_depth')
# (1633757478.7954257, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.7961984, 'Image', '/camera2/image_raw/image_color')
# (1633757478.7967958, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.838772, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.8390756, 'Image', '/camera2/image_raw/image_color')
# (1633757478.8854995, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.8865027, 'Image', '/image_depth2/image_depth')
# (1633757478.8865566, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.8875773, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757478.8883128, 'Image', '/camera2/image_raw/image_color')
# (1633757478.93307, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.933371, 'Image', '/camera2/image_raw/image_color')
# (1633757478.979393, 'CameraInfo', '/image_depth2/camera_info')
# (1633757478.9805605, 'Image', '/image_depth2/image_depth')
# (1633757478.981559, 'Image', '/camera2/image_raw/image_color')
# (1633757478.981737, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757478.9822986, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.0108163, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.0604346, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.0612302, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.0613244, 'Image', '/image_depth2/image_depth')
# (1633757479.0617197, 'Image', '/camera2/image_raw/image_color')
# (1633757479.112846, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.1135511, 'Image', '/image_depth2/image_depth')
# (1633757479.1136656, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.1141868, 'Image', '/camera2/image_raw/image_color')
# (1633757479.141907, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.1914494, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.1924033, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.1924105, 'Image', '/image_depth2/image_depth')
# (1633757479.1930106, 'Image', '/camera2/image_raw/image_color')
# (1633757479.2214692, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.2717648, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.272441, 'Image', '/image_depth2/image_depth')
# (1633757479.2727997, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.273273, 'Image', '/camera2/image_raw/image_color')
# (1633757479.3160815, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.3666239, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.3675191, 'Image', '/image_depth2/image_depth')
# (1633757479.3675914, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.3682778, 'Image', '/camera2/image_raw/image_color')
# (1633757479.395462, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.445632, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.446428, 'Image', '/image_depth2/image_depth')
# (1633757479.4466834, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.4472907, 'Image', '/camera2/image_raw/image_color')
# (1633757479.4747174, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.524481, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.5252085, 'Image', '/image_depth2/image_depth')
# (1633757479.5252867, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.5258787, 'Image', '/camera2/image_raw/image_color')
# (1633757479.570882, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.6226184, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.6233788, 'Image', '/image_depth2/image_depth')
# (1633757479.623669, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.6243222, 'Image', '/camera2/image_raw/image_color')
# (1633757479.651421, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.7007172, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.7015035, 'Image', '/image_depth2/image_depth')
# (1633757479.7019017, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.7023308, 'Image', '/camera2/image_raw/image_color')
# (1633757479.7298927, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.7787516, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.7795725, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.7797077, 'Image', '/image_depth2/image_depth')
# (1633757479.7800279, 'Image', '/camera2/image_raw/image_color')
# (1633757479.8080423, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.8581858, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.858976, 'Image', '/image_depth2/image_depth')
# (1633757479.8591423, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.8596053, 'Image', '/camera2/image_raw/image_color')
# (1633757479.887823, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757479.9382935, 'CameraInfo', '/image_depth2/camera_info')
# (1633757479.9389668, 'Image', '/image_depth2/image_depth')
# (1633757479.9393256, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757479.939681, 'Image', '/camera2/image_raw/image_color')
# (1633757479.982115, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.032184, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.0329862, 'Image', '/image_depth2/image_depth')
# (1633757480.0332983, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.0336468, 'Image', '/camera2/image_raw/image_color')
# (1633757480.0607817, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.1108987, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.1116152, 'Image', '/image_depth2/image_depth')
# (1633757480.1117718, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.1122317, 'Image', '/camera2/image_raw/image_color')
# (1633757480.140105, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.194577, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.1956325, 'Image', '/image_depth2/image_depth')
# (1633757480.1973019, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.1979902, 'Image', '/camera2/image_raw/image_color')
# (1633757480.236588, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.2869234, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.2877157, 'Image', '/image_depth2/image_depth')
# (1633757480.2879505, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.288554, 'Image', '/camera2/image_raw/image_color')
# (1633757480.3163302, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.3662262, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.3668334, 'Image', '/image_depth2/image_depth')
# (1633757480.367223, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.3676198, 'Image', '/camera2/image_raw/image_color')
# (1633757480.427024, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.4276388, 'Image', '/camera2/image_raw/image_color')
# (1633757480.4278562, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.448419, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.4489741, 'Image', '/image_depth2/image_depth')
# (1633757480.4809778, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.4813702, 'Image', '/camera2/image_raw/image_color')
# (1633757480.5280788, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.5291715, 'Image', '/image_depth2/image_depth')
# (1633757480.5295973, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.5301406, 'Image', '/camera2/image_raw/image_color')
# (1633757480.530229, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.5622327, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.5625644, 'Image', '/camera2/image_raw/image_color')
# (1633757480.6084404, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.6094463, 'Image', '/image_depth2/image_depth')
# (1633757480.609766, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.6103995, 'Image', '/camera2/image_raw/image_color')
# (1633757480.610564, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.642773, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.6430273, 'Image', '/camera2/image_raw/image_color')
# (1633757480.689186, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.6903155, 'Image', '/image_depth2/image_depth')
# (1633757480.6903408, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.6904564, 'Image', '/camera2/image_raw/image_color')
# (1633757480.6910858, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.7366493, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.7369754, 'Image', '/camera2/image_raw/image_color')
# (1633757480.7822607, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.7834196, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.7837753, 'Image', '/image_depth2/image_depth')
# (1633757480.784076, 'Image', '/camera2/image_raw/image_color')
# (1633757480.7846587, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.8363903, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.8370936, 'Image', '/image_depth2/image_depth')
# (1633757480.8373213, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.8379261, 'Image', '/camera2/image_raw/image_color')
# (1633757480.8654675, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757480.9152727, 'CameraInfo', '/image_depth2/camera_info')
# (1633757480.9160113, 'Image', '/image_depth2/image_depth')
# (1633757480.9166563, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757480.9170582, 'Image', '/camera2/image_raw/image_color')
# (1633757480.9597228, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757481.0116277, 'CameraInfo', '/image_depth2/camera_info')
# (1633757481.0122848, 'Image', '/image_depth2/image_depth')
# (1633757481.012703, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757481.0131826, 'Image', '/camera2/image_raw/image_color')
# (1633757481.0409718, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757481.0909092, 'CameraInfo', '/image_depth2/camera_info')
# (1633757481.0916398, 'Image', '/image_depth2/image_depth')
# (1633757481.0920527, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757481.0925212, 'Image', '/camera2/image_raw/image_color')
# (1633757481.153764, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757481.1543221, 'Image', '/camera2/image_raw/image_color')
# (1633757481.1545136, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757481.2012134, 'CameraInfo', '/image_depth2/camera_info')
# (1633757481.202093, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757481.2021632, 'Image', '/image_depth2/image_depth')
# (1633757481.202971, 'Image', '/camera2/image_raw/image_color')
# (1633757481.2032819, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# ...
# (1633757481.96727, 'Image', '/camera2/image_raw/image_color')
# (1633757481.9947093, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.045944, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.0467632, 'Image', '/image_depth2/image_depth')
# (1633757482.046846, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.0474622, 'Image', '/camera2/image_raw/image_color')
# (1633757482.0758476, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.127268, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.1281033, 'Image', '/image_depth2/image_depth')
# (1633757482.12847, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.1290348, 'Image', '/camera2/image_raw/image_color')
# (1633757482.1713057, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.2220674, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.2228115, 'Image', '/image_depth2/image_depth')
# (1633757482.2229555, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.2234354, 'Image', '/camera2/image_raw/image_color')
# (1633757482.266036, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.3268285, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.3277242, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.327811, 'Image', '/image_depth2/image_depth')
# (1633757482.328598, 'Image', '/camera2/image_raw/image_color')
# (1633757482.3289962, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.3818567, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.3826842, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.3827271, 'Image', '/image_depth2/image_depth')
# (1633757482.3832612, 'Image', '/camera2/image_raw/image_color')
# (1633757482.4112747, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.4649355, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.4662, 'Image', '/image_depth2/image_depth')
# (1633757482.4677541, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.4685955, 'Image', '/camera2/image_raw/image_color')
# (1633757482.5079591, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.5579925, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.5586696, 'Image', '/image_depth2/image_depth')
# (1633757482.558949, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.5594387, 'Image', '/camera2/image_raw/image_color')
# (1633757482.6191545, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.6198187, 'Image', '/camera2/image_raw/image_color')
# (1633757482.6198568, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.666127, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.667172, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.6672213, 'Image', '/image_depth2/image_depth')
# (1633757482.6679456, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.6682453, 'Image', '/camera2/image_raw/image_color')
# (1633757482.7141361, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.7143822, 'Image', '/camera2/image_raw/image_color')
# (1633757482.7603924, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.761312, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.7616625, 'Image', '/image_depth2/image_depth')
# (1633757482.7620823, 'Image', '/camera2/image_raw/image_color')
# (1633757482.7623553, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.794486, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.7948365, 'Image', '/camera2/image_raw/image_color')
# (1633757482.8421726, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.8430955, 'Image', '/image_depth2/image_depth')
# (1633757482.843654, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.8442676, 'Image', '/camera2/image_raw/image_color')
# (1633757482.8445125, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.8898904, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.8902404, 'Image', '/camera2/image_raw/image_color')
# (1633757482.940127, 'CameraInfo', '/image_depth2/camera_info')
# (1633757482.9417357, 'Image', '/image_depth2/image_depth')
# (1633757482.942655, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.943482, 'Image', '/camera2/image_raw/image_color')
# (1633757482.944421, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757482.9868188, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757482.9870658, 'Image', '/camera2/image_raw/image_color')
# (1633757483.0394425, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.0404303, 'Image', '/image_depth2/image_depth')
# (1633757483.0421624, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.0429194, 'Image', '/camera2/image_raw/image_color')
# (1633757483.0437145, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.0795877, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.133582, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.1345644, 'Image', '/image_depth2/image_depth')
# (1633757483.1360946, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.136818, 'Image', '/camera2/image_raw/image_color')
# (1633757483.1760726, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.226672, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.227429, 'Image', '/image_depth2/image_depth')
# (1633757483.2275953, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.2282734, 'Image', '/camera2/image_raw/image_color')
# (1633757483.2885633, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.2892818, 'Image', '/camera2/image_raw/image_color')
# (1633757483.289627, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.3104725, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.3109345, 'Image', '/image_depth2/image_depth')
# (1633757483.3410332, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.3413868, 'Image', '/camera2/image_raw/image_color')
# (1633757483.3869603, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.3879116, 'Image', '/image_depth2/image_depth')
# (1633757483.3880572, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.3887513, 'Image', '/camera2/image_raw/image_color')
# (1633757483.3892963, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.417913, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.468486, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.4694006, 'Image', '/image_depth2/image_depth')
# (1633757483.4696383, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.470135, 'Image', '/camera2/image_raw/image_color')
# (1633757483.512576, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.562984, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.5638554, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.5640597, 'Image', '/image_depth2/image_depth')
# (1633757483.5645132, 'Image', '/camera2/image_raw/image_color')
# (1633757483.5922782, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.6448295, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.6456609, 'Image', '/image_depth2/image_depth')
# (1633757483.646262, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.646857, 'Image', '/camera2/image_raw/image_color')
# (1633757483.6877246, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.7424002, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.7435305, 'Image', '/image_depth2/image_depth')
# (1633757483.7447858, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.7455356, 'Image', '/camera2/image_raw/image_color')
# (1633757483.7851536, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.8355079, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.8365579, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.8365579, 'Image', '/image_depth2/image_depth')
# (1633757483.8371353, 'Image', '/camera2/image_raw/image_color')
# (1633757483.8651266, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757483.919893, 'CameraInfo', '/image_depth2/camera_info')
# (1633757483.922305, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757483.922629, 'Image', '/image_depth2/image_depth')
# (1633757483.92315, 'Image', '/camera2/image_raw/image_color')
# (1633757483.9642086, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.017243, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.018166, 'Image', '/image_depth2/image_depth')
# (1633757484.0181954, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.018966, 'Image', '/camera2/image_raw/image_color')
# (1633757484.0466964, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.097068, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.0978959, 'Image', '/image_depth2/image_depth')
# (1633757484.0981896, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.0987794, 'Image', '/camera2/image_raw/image_color')
# (1633757484.1409836, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.1909719, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.1917968, 'Image', '/image_depth2/image_depth')
# (1633757484.191885, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.1924458, 'Image', '/camera2/image_raw/image_color')
# (1633757484.251949, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.2526174, 'Image', '/camera2/image_raw/image_color')
# (1633757484.2528996, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.2999272, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.300856, 'Image', '/image_depth2/image_depth')
# (1633757484.3011074, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.301779, 'Image', '/camera2/image_raw/image_color')
# (1633757484.3020375, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.347803, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.348344, 'Image', '/camera2/image_raw/image_color')
# (1633757484.395551, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.3964832, 'Image', '/image_depth2/image_depth')
# (1633757484.396578, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.3974588, 'Image', '/camera2/image_raw/image_color')
# (1633757484.3974957, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.4433074, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.4436257, 'Image', '/camera2/image_raw/image_color')
# (1633757484.4899411, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.4910374, 'Image', '/image_depth2/image_depth')
# (1633757484.4914145, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.4920037, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.4923012, 'Image', '/camera2/image_raw/image_color')
# (1633757484.544451, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.5452516, 'Image', '/image_depth2/image_depth')
# (1633757484.5456698, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.5462582, 'Image', '/camera2/image_raw/image_color')
# (1633757484.5743272, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.6253238, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.6260726, 'Image', '/image_depth2/image_depth')
# (1633757484.6265168, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.6269166, 'Image', '/camera2/image_raw/image_color')
# (1633757484.669243, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.720992, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.721826, 'Image', '/image_depth2/image_depth')
# (1633757484.722113, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.7226768, 'Image', '/camera2/image_raw/image_color')
# (1633757484.7642388, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.8251424, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.8261921, 'Image', '/image_depth2/image_depth')
# (1633757484.8262553, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.8269289, 'Image', '/camera2/image_raw/image_color')
# (1633757484.8270674, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.8597383, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.860136, 'Image', '/camera2/image_raw/image_color')
# (1633757484.9060705, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.9070666, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.9074886, 'Image', '/image_depth2/image_depth')
# (1633757484.9078765, 'Image', '/camera2/image_raw/image_color')
# (1633757484.907968, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757484.9404688, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.940911, 'Image', '/camera2/image_raw/image_color')
# (1633757484.987189, 'CameraInfo', '/image_depth2/camera_info')
# (1633757484.988189, 'Image', '/image_depth2/image_depth')
# (1633757484.9884439, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757484.989322, 'Image', '/camera2/image_raw/image_color')
# (1633757484.9896493, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.0221033, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.0224166, 'Image', '/camera2/image_raw/image_color')
# (1633757485.0690012, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.0698156, 'Image', '/image_depth2/image_depth')
# (1633757485.0698357, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.071296, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.071583, 'Image', '/camera2/image_raw/image_color')
# (1633757485.1174877, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.1178465, 'Image', '/camera2/image_raw/image_color')
# (1633757485.1644945, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.165588, 'Image', '/image_depth2/image_depth')
# (1633757485.1656163, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.1662672, 'Image', '/camera2/image_raw/image_color')
# (1633757485.166921, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.2128747, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.2131674, 'Image', '/camera2/image_raw/image_color')
# (1633757485.2607627, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.2617698, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.261812, 'Image', '/image_depth2/image_depth')
# (1633757485.262536, 'Image', '/camera2/image_raw/image_color')
# (1633757485.26272, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.3091621, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.3095205, 'Image', '/camera2/image_raw/image_color')
# (1633757485.355856, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.3567915, 'Image', '/image_depth2/image_depth')
# (1633757485.356966, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.3575962, 'Image', '/camera2/image_raw/image_color')
# (1633757485.3577368, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.4099226, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.4107482, 'Image', '/image_depth2/image_depth')
# (1633757485.4110553, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.4114988, 'Image', '/camera2/image_raw/image_color')
# (1633757485.4389417, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.489984, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.4905686, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.4908357, 'Image', '/image_depth2/image_depth')
# (1633757485.4910593, 'Image', '/camera2/image_raw/image_color')
# (1633757485.533874, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.585134, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.5858922, 'Image', '/image_depth2/image_depth')
# (1633757485.5859394, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.5865438, 'Image', '/camera2/image_raw/image_color')
# (1633757485.6457775, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.6464105, 'Image', '/camera2/image_raw/image_color')
# (1633757485.6466541, 'Image', '/sparus2/Blue_view_M900_FLS2/display')
# (1633757485.6925542, 'CameraInfo', '/image_depth2/camera_info')
# (1633757485.6934557, 'CameraInfo', '/camera2/image_raw/camera_info')
# (1633757485.6937559, 'Image', '/image_depth2/image_depth')
# (1633757485.6941707, 'Image', '/camera2/image_raw/image_color')
# (1633757485.694408, 'Image', '/sparus2/Blue_view_M900_FLS2/display')

# %%
print(counter)
# Out:
# defaultdict(<function <lambda> at 0x7f2354e40bd0>, {'/sparus2/Blue_view_M900_FLS2/display': 175, '/camera2/image_raw/image_color': 249, '/image_depth2/camera_info': 182, '/camera2/image_raw/camera_info': 249, '/image_depth2/image_depth': 182})
